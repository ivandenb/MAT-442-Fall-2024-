# %% [markdown]
# <a href="https://colab.research.google.com/github/ivandenb/MAT-442-Fall-2024-/blob/main/HW2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Independent Variables and Random Samples**

# %% [markdown]
# 2.3.1 Joint Probability Distributions

# %% [markdown]
# We will find the joint probability of 4 different objects with independent lifetimes.

# %% [markdown]
# The lifetimes will be of an exponential distribution

# %%
#imports
import numpy as np
import pandas as pd

#set the parameters of each lifetime
param1=200
param2=400
param3=600
param4=800

#print the parameters
print("Parameter 1: ", param1)
print("Parameter 2: ", param2)
print("Parameter 3: ", param3)
print("Parameter 4: ", param4)
# Out:
# Parameter 1:  200
# Parameter 2:  400
# Parameter 3:  600
# Parameter 4:  800

# %% [markdown]
# Based on the parameters for each item we will find the probability that the lifetimes of all the items is 550 days

# %%
#set the expected lifetime
expected_lifetime=550

#calculate the probability using joint distribution
probability=np.exp(-param1/expected_lifetime)*np.exp(-param2/expected_lifetime)*np.exp(-param3/expected_lifetime)*np.exp(-param4/expected_lifetime)

#print the probability
print("The probability that the lifetimes of all the items is 550 days is: ", probability)
# Out:
# The probability that the lifetimes of all the items is 550 days is:  0.02634798081444873

# %% [markdown]
# Thus joint probabiltiy distribution of 4 different random variables has been shown

# %% [markdown]
# 2.3.2 Correlation and Dependence

# %% [markdown]
# We will generate three scatter plots with 1, 0, and -1 correlation

# %%
# import
import matplotlib.pyplot as plt

# Generate data with correlation 1 with 50 points
np.random.seed(0)
x1 = np.random.rand(50)
y1 = x1

# Generate data with correlation 0 with 50 point
x2 = np.random.rand(50)
y2 = np.random.rand(50)

# Generate data with correlation -1 with 50 points
x3 = np.random.rand(50)
y3 = 1 - x3

# %% [markdown]
# With the data generated, the three plots will now be generated

# %%
# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot 1
axes[0].scatter(x1, y1)
axes[0].set_title('Correlation = 1')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')

# Plot 2
axes[1].scatter(x2, y2)
axes[1].set_title('Correlation = 0')
axes[1].set_xlabel('X')
axes[1].set_ylabel('Y')

# Plot 3
axes[2].scatter(x3, y3)
axes[2].set_title('Correlation = -1')
axes[2].set_xlabel('X')
axes[2].set_ylabel('Y')

plt.tight_layout()
plt.show()

# %% [markdown]
# And thus there are plots for 1, 0, and -1 correlation as shown above

# %% [markdown]
# 2.3.3 Random Samples

# %% [markdown]
# Demonstrating the normal shape of taking random samples from an exponential function when plotting their means

# %% [markdown]
# First set the parameters for the population being sampled, with a population size of 1000 with 100 samples of size 30

# %%
# Set parameters for the example
population_size = 10000
num_samples = 100
sample_size = 30

# %% [markdown]
# Now create the exponential population

# %%
# Exponential population
population = np.random.exponential(scale=5, size=population_size)

# %% [markdown]
# Now take the samples and find their means

# %%
# Draw multiple samples and calculate their means
sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# %% [markdown]
# Now plot the histogram of the sample means

# %%
# Create the histogram of sample means
plt.figure(figsize=(8, 6))
plt.hist(sample_means, bins=20, edgecolor='black')
plt.xlabel('Sample Means')
plt.ylabel('Frequency')
plt.title('Distribution of Sample Means')
plt.show()

# %% [markdown]
# From the graph you can clearly see the normal shape of the graph

# %%
# Calculate parameters for the normal curve
mean_sample_means = np.mean(sample_means)
std_sample_means = np.std(sample_means)

# Generate x values for the normal curve
x = np.linspace(mean_sample_means - 3 * std_sample_means, mean_sample_means + 3 * std_sample_means, 100)

# Calculate y values for the normal curve
y = norm.pdf(x, loc=mean_sample_means, scale=std_sample_means)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(sample_means, bins=20, edgecolor='black', density=True, alpha=0.6)

# Plot the normal curve on top of the histogram
plt.plot(x, y, 'r', label='Normal Curve')
plt.xlabel('Sample Means')
plt.ylabel('Frequency')
plt.title('Distribution of Sample Means with Normal Curve')
plt.legend()
plt.show()

# %% [markdown]
# And thus the normal nature of the means of the samples is close to normal
